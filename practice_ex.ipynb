# %%
import numpy as np
import pandas as pd

# %%
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
plt.plot([1,2,3],[3,4,9])
plt.show()

# %%
plt.plot([1,2,3],[3,4,9])
plt.title("Simple Data")
plt.ylabel("Y axis")
plt.xlabel("X axis")
plt.show()

# %%
x=[12,15,19]
y=[21,50,60]
x2=[23,34,89]
y2=[11,82,38]

plt.plot(x,y, label="First")
# plt.scatter(x,y, label="First")
plt.plot(x2,y2, label="Second", linewidth=3)
plt.legend()
plt.show()

# %%
a=np.array([[2,4],[3,5],[7,8]])
b=a[[0,1,2],[0,1,0]]
print(b)
# Out:
# [2 5 7]
